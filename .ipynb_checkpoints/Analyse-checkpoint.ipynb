# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from pandas import Series

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('csv/martinus_sk.csv', sep=',', low_memory=False)
df_db = pd.read_csv('csv/martinus_db.csv', sep=',', low_memory=False)
print (len(df))
print (len(df_db))
# Out:
# 474
# 3295

# %%
print (df.columns)
print (df_db.columns)
# Out:
# Index(['code', 'date', 'comments', 'likes', 'caption', 'image'], dtype='object')
# Index(['title', 'price'], dtype='object')

# %%
df.reset_index(inplace=True)
df.head(11)
# Out:
#     index         code        date  comments  likes  \
# 0       0  BL0g9FMgm9L  1477043403         4    106
# 1       1  BLyLQkNg8hb  1476964919         5    236
# 2       2  BLsyIhQgRD8  1476783974         0    665
# 3       3  BLlWmEJgaHa  1476534655         3    216
# 4       4  BLiJIdagN63  1476426933         0    303
# 5       5  BLfsgqlBu_6  1476344818        12    400
# 6       6  BLbaX-1As1X  1476201092         2    340
# 7       7  BLYRCu4AD9a  1476095536         8    326
# 8       8  BLSrJ3XgJCV  1475907900         5    419
# 9       9  BLItcpPA9jD  1475573558         6    413
# 10     10  BLGImoCAc7t  1475487132        11    529
#
#                                               caption  \
# 0   Na našom Youtube kanále nájdete najnovší diel ...
# 1   Naša Borka, ktorú môžete stretnúť v kníhkupect...
# 2   K tomuto počasiu sa hodia skôr teplé nápoje, a...
# 3   Aký máte zatiaľ víkend? Ak hľadáte inšpiráciu ...
# 4   Aj vy už máte nachystanú kôpku kníh na víkend?...
# 5   Aha, čo nám práve dorazilo na sklad. Nový Geor...
# 6   Nové číslo magazínu O knihách rozdávame k náku...
# 7   Waw! Naše kníhkupectvo v Cubicone sa objavilo ...
# 8   Dobré ránko! Víkend si zaslúži pomalé raňajky ...
# 9   Toto daždivé jesenné počasie si pýta teplý šál...
# 10  Priznajte sa, koho víkend vyzeral takto? 😊Nový...
#
#                                                 image
# 0   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 1   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 2   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 3   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 4   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 5   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 6   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 7   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 8   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 9   https://scontent-fra3-1.cdninstagram.com/t51.2...
# 10  https://scontent-fra3-1.cdninstagram.com/t51.2...

# %%
df = df.drop('code', 1)
df = df.drop('image', 1)
df.head(11)
# Out:
#     index        date  comments  likes  \
# 0       0  1477043403         4    106
# 1       1  1476964919         5    236
# 2       2  1476783974         0    665
# 3       3  1476534655         3    216
# 4       4  1476426933         0    303
# 5       5  1476344818        12    400
# 6       6  1476201092         2    340
# 7       7  1476095536         8    326
# 8       8  1475907900         5    419
# 9       9  1475573558         6    413
# 10     10  1475487132        11    529
#
#                                               caption
# 0   Na našom Youtube kanále nájdete najnovší diel ...
# 1   Naša Borka, ktorú môžete stretnúť v kníhkupect...
# 2   K tomuto počasiu sa hodia skôr teplé nápoje, a...
# 3   Aký máte zatiaľ víkend? Ak hľadáte inšpiráciu ...
# 4   Aj vy už máte nachystanú kôpku kníh na víkend?...
# 5   Aha, čo nám práve dorazilo na sklad. Nový Geor...
# 6   Nové číslo magazínu O knihách rozdávame k náku...
# 7   Waw! Naše kníhkupectvo v Cubicone sa objavilo ...
# 8   Dobré ránko! Víkend si zaslúži pomalé raňajky ...
# 9   Toto daždivé jesenné počasie si pýta teplý šál...
# 10  Priznajte sa, koho víkend vyzeral takto? 😊Nový...

# %%
df = df.drop_duplicates()
df_db = df_db.drop_duplicates()

# %%
df_db.head(11)
# Out:
#                                                 title    price
# 0                 Domácí krabičková dieta 1 - 3 - BOX  26,92 €
# 1                            Divá Bára / Dobrý člověk   7,76 €
# 2   Doplňkový odpor v tréninku rychlostních schopn...  11,66 €
# 3                            Myslivecké příběhy z hor  10,49 €
# 4   Ráchel a Lars (Obrázkový deník dvojího odcházení)  17,58 €
# 5                           Winx club - Omalovánky A4   2,35 €
# 6                                  Ztraceno ve vlnách  12,44 €
# 7   Support (Ako vybudovať úspešný biznis, aj keď ...  11,49 €
# 8                                             Trhlina  10,32 €
# 9                                Smrť na druhom brehu  10,36 €
# 10                      Tanec s drakmi 1: Sny a Prach  15,12 €

# %%
title = df_db["title"]
title = title.str.strip().str.lower().str.replace(" ", "")

# %%
import string
exclude = set(string.punctuation)
def remove_punctuation(title):
    title = ''.join(ch for ch in title if ch not in exclude)
    return title
    
title = title.apply(remove_punctuation)

# %%
import unicodedata
def remove_accents(title):
    nfkd_form = unicodedata.normalize('NFKD', title)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii

title = title.apply(remove_accents)

# %%
title = title.str.decode("utf-8")
df_db["edited_title"] = title
df_db.head(11)
# Out:
#                                                 title    price  \
# 0                 Domácí krabičková dieta 1 - 3 - BOX  26,92 €
# 1                            Divá Bára / Dobrý člověk   7,76 €
# 2   Doplňkový odpor v tréninku rychlostních schopn...  11,66 €
# 3                            Myslivecké příběhy z hor  10,49 €
# 4   Ráchel a Lars (Obrázkový deník dvojího odcházení)  17,58 €
# 5                           Winx club - Omalovánky A4   2,35 €
# 6                                  Ztraceno ve vlnách  12,44 €
# 7   Support (Ako vybudovať úspešný biznis, aj keď ...  11,49 €
# 8                                             Trhlina  10,32 €
# 9                                Smrť na druhom brehu  10,36 €
# 10                      Tanec s drakmi 1: Sny a Prach  15,12 €
#
#                                          edited_title
# 0                          domacikrabickovadieta13box
# 1                                 divabaradobryclovek
# 2       doplnkovyodporvtreninkurychlostnichschopnosti
# 3                               mysliveckepribehyzhor
# 4           rachelalarsobrazkovydenikdvojihoodchazeni
# 5                                winxclubomalovankya4
# 6                                    ztracenovevlnach
# 7   supportakovybudovatuspesnybiznisajkedrobitejed...
# 8                                             trhlina
# 9                                   smrtnadruhombrehu
# 10                             tanecsdrakmi1snyaprach

# %%
results = pd.Series(df["caption"]).str.extractall('(?P<hashtag>[#]+)(\w*)')
results
# Out:
#           hashtag                       1
#     match
# 0   0           #        martinusaciradia
#     1           #                martinus
#     2           #              martinussk
#     3           #                   knihy
#     4           #                   kniha
#     5           #                   citam
#     6           #              pravecitam
#     7           #                 cocitat
#     8           #       viaccasunacitanie
#     9           #                    sova
#     10          #              tipnaknihu
# 1   0           #              martinussk
#     1           #             martinusaci
#     2           #          borkazcubiconu
#     3           #       pippidlhapancucha
#     4           #             slovart_vyd
#     5           #   podobnostcistonahodna
# 2   0           #                   knihy
#     1           #              martinussk
#     2           #           severskakrimi
#     3           #            vludskejkozi
#     4           #            jørgenbrekke
#     5           #   vydavatelstvopremedia
#     6           #          martinushrncek
# 3   0           #              tipnaknihu
#     1           #              martinussk
#     2           #                   knihy
#     3           #                  vikend
#     4           #       viaccasunacitanie
#     5           #       viaccasunapecenie
# ...           ...                     ...
# 469 6           #          martinushrncek
# 470 0           #              tipnaknihu
#     1           #              martinussk
#     2           #                   knihy
#     3           #                  vikend
#     4           #       viaccasunacitanie
#     5           #       viaccasunapecenie
#     6           #         thestoryofacake
#     7           #     thestoryofacakeblog
#     8           #          stvoryzkuchyne
#     9           #          miriamkalisova
#     10          #     niesomziadnababovka
#     11          #  pribehnovehopriezviska
# 471 0           #                  vikend
#     1           #       viaccasunacitanie
#     2           #              martinussk
#     3           #                  oddych
#     4           #           pohodasknihou
#     5           #           jesensknihami
# 472 0           #              tipnaknihu
#     1           #              martinussk
#     2           #            tanecsdrakmi
#     3           #          georgerrmartin
#     4           #                 novinka
#     5           #      ziskajsijejpriazen
# 473 0           #              martinussk
#     1           #                     sme
#     2           #         magazinoknihach
#     3           #             harrypotter
#     4           #      harrypotterforever
#
# [2422 rows x 2 columns]

# %%
results1 = results.xs(3, level="match")

# %%
all_hastags = []

for i in range(0,10):
    results.xs(i, level="match")
    all_hastags.append(results[1].tolist())
    
print (len(all_hastags[0]))
# Out:
# 2422

# %%
b = df_db["edited_title"].tolist()
results.reset_index(inplace=True)  

final = []
for bd in b:
    try:
        if bd in all_hastags[0]:
            final.append(bd)
    except:
        pass


df_new = results[results[1].isin(final) == True]
print (len(df_new))
# Out:
# 35

# %%
merged_inner = pd.merge(left=df_new,right=df, left_on='level_0', right_on='index')
merged_inner.head(11)
# Out:
#     level_0  match hashtag                             1  index        date  \
# 0         0      9       #                          sova      0  1477043403
# 1         2      3       #                  vludskejkozi      2  1476783974
# 2         3     10       #           niesomziadnababovka      3  1476534655
# 3         3     11       #        pribehnovehopriezviska      3  1476534655
# 4         5      5       #            ziskajsijejpriazen      5  1476344818
# 5         7      5       #                   dankaajanka      7  1476095536
# 6         9      3       #                 dievcavovlaku      9  1475573558
# 7        13     14       #              harrypotter17box     13  1475142446
# 8        16      5       #  najkrajsieslovenskerozpravky     16  1474533750
# 9        29      5       #               peklojeotvorene     29  1472036874
# 10       62      8       #             genialnapriatelka     62  1467809786
#
#     comments  likes                                            caption
# 0          4    106  Na našom Youtube kanále nájdete najnovší diel ...
# 1          0    665  K tomuto počasiu sa hodia skôr teplé nápoje, a...
# 2          3    216  Aký máte zatiaľ víkend? Ak hľadáte inšpiráciu ...
# 3          3    216  Aký máte zatiaľ víkend? Ak hľadáte inšpiráciu ...
# 4         12    400  Aha, čo nám práve dorazilo na sklad. Nový Geor...
# 5          8    326  Waw! Naše kníhkupectvo v Cubicone sa objavilo ...
# 6          6    413  Toto daždivé jesenné počasie si pýta teplý šál...
# 7          4    336  Kto si ešte dnes do 15:00 predobjedná nového H...
# 8          4    225  Aká je vaša obľúbená jesenná kniha? Čo takto f...
# 9          4    156  Druhý detektívny román od vynikajúceho autora ...
# 10         1    188  Geniálna priateľka od Eleny Ferrante sa dočkal...

# %%
merged_inner = merged_inner.drop('match', axis = 1)
merged_inner = merged_inner.drop('hashtag', axis = 1)
merged_inner = merged_inner.drop('level_0', axis = 1)
merged_inner.head(11)
# Out:
#                                1  index        date  comments  likes  \
# 0                           sova      0  1477043403         4    106
# 1                   vludskejkozi      2  1476783974         0    665
# 2            niesomziadnababovka      3  1476534655         3    216
# 3         pribehnovehopriezviska      3  1476534655         3    216
# 4             ziskajsijejpriazen      5  1476344818        12    400
# 5                    dankaajanka      7  1476095536         8    326
# 6                  dievcavovlaku      9  1475573558         6    413
# 7               harrypotter17box     13  1475142446         4    336
# 8   najkrajsieslovenskerozpravky     16  1474533750         4    225
# 9                peklojeotvorene     29  1472036874         4    156
# 10             genialnapriatelka     62  1467809786         1    188
#
#                                               caption
# 0   Na našom Youtube kanále nájdete najnovší diel ...
# 1   K tomuto počasiu sa hodia skôr teplé nápoje, a...
# 2   Aký máte zatiaľ víkend? Ak hľadáte inšpiráciu ...
# 3   Aký máte zatiaľ víkend? Ak hľadáte inšpiráciu ...
# 4   Aha, čo nám práve dorazilo na sklad. Nový Geor...
# 5   Waw! Naše kníhkupectvo v Cubicone sa objavilo ...
# 6   Toto daždivé jesenné počasie si pýta teplý šál...
# 7   Kto si ešte dnes do 15:00 predobjedná nového H...
# 8   Aká je vaša obľúbená jesenná kniha? Čo takto f...
# 9   Druhý detektívny román od vynikajúceho autora ...
# 10  Geniálna priateľka od Eleny Ferrante sa dočkal...

# %%
merged_left = pd.merge(left=merged_inner,right=df_db, how='inner', left_on=1, right_on='edited_title')
merged_left = merged_left.drop_duplicates([1, 'edited_title'])
merged_left.head(11)
# Out:
#                                1  index        date  comments  likes  \
# 0                           sova      0  1477043403         4    106
# 1                   vludskejkozi      2  1476783974         0    665
# 3            niesomziadnababovka      3  1476534655         3    216
# 5         pribehnovehopriezviska      3  1476534655         3    216
# 7             ziskajsijejpriazen      5  1476344818        12    400
# 9                    dankaajanka      7  1476095536         8    326
# 10                 dievcavovlaku      9  1475573558         6    413
# 12              harrypotter17box     13  1475142446         4    336
# 14  najkrajsieslovenskerozpravky     16  1474533750         4    225
# 15               peklojeotvorene     29  1472036874         4    156
# 16             genialnapriatelka     62  1467809786         1    188
#
#                                               caption  \
# 0   Na našom Youtube kanále nájdete najnovší diel ...
# 1   K tomuto počasiu sa hodia skôr teplé nápoje, a...
# 3   Aký máte zatiaľ víkend? Ak hľadáte inšpiráciu ...
# 5   Aký máte zatiaľ víkend? Ak hľadáte inšpiráciu ...
# 7   Aha, čo nám práve dorazilo na sklad. Nový Geor...
# 9   Waw! Naše kníhkupectvo v Cubicone sa objavilo ...
# 10  Toto daždivé jesenné počasie si pýta teplý šál...
# 12  Kto si ešte dnes do 15:00 predobjedná nového H...
# 14  Aká je vaša obľúbená jesenná kniha? Čo takto f...
# 15  Druhý detektívny román od vynikajúceho autora ...
# 16  Geniálna priateľka od Eleny Ferrante sa dočkal...
#
#                              title    price                  edited_title
# 0                             Sova  12,72 €                          sova
# 1                   V ľudskej koži  11,01 €                  vludskejkozi
# 3           Nie som žiadna bábovka  13,52 €           niesomziadnababovka
# 5         Príbeh nového priezviska  13,80 €        pribehnovehopriezviska
# 7            Získaj si jej priazeň  10,59 €            ziskajsijejpriazen
# 9                    Danka a Janka   5,52 €                   dankaajanka
# 10                 Dievča vo vlaku  10,64 €                 dievcavovlaku
# 12        Harry Potter 1 - 7 (box)  53,31 €              harrypotter17box
# 14  Najkrajšie slovenské rozprávky  17,79 €  najkrajsieslovenskerozpravky
# 15               Peklo je otvorené  12,42 €               peklojeotvorene
# 16              Geniálna priateľka  12,45 €             genialnapriatelka

# %%
merged_left = merged_left.drop([1, 'caption', 'edited_title'], axis=1)
merged_left.head(11)
# Out:
#     index        date  comments  likes                           title  \
# 0       0  1477043403         4    106                            Sova
# 1       2  1476783974         0    665                  V ľudskej koži
# 3       3  1476534655         3    216          Nie som žiadna bábovka
# 5       3  1476534655         3    216        Príbeh nového priezviska
# 7       5  1476344818        12    400           Získaj si jej priazeň
# 9       7  1476095536         8    326                   Danka a Janka
# 10      9  1475573558         6    413                 Dievča vo vlaku
# 12     13  1475142446         4    336        Harry Potter 1 - 7 (box)
# 14     16  1474533750         4    225  Najkrajšie slovenské rozprávky
# 15     29  1472036874         4    156               Peklo je otvorené
# 16     62  1467809786         1    188              Geniálna priateľka
#
#       price
# 0   12,72 €
# 1   11,01 €
# 3   13,52 €
# 5   13,80 €
# 7   10,59 €
# 9    5,52 €
# 10  10,64 €
# 12  53,31 €
# 14  17,79 €
# 15  12,42 €
# 16  12,45 €

# %%
import datetime 
def convert_date(date):
    new_date = datetime.datetime.fromtimestamp(int(date)).strftime('%d-%m-%Y')
    return new_date
date = merged_left["date"]
date = date.apply(convert_date)
merged_left["date"] = date
merged_left.head(11)
# Out:
#     index        date  comments  likes                           title  \
# 0       0  21-10-2016         4    106                            Sova
# 1       2  18-10-2016         0    665                  V ľudskej koži
# 3       3  15-10-2016         3    216          Nie som žiadna bábovka
# 5       3  15-10-2016         3    216        Príbeh nového priezviska
# 7       5  13-10-2016        12    400           Získaj si jej priazeň
# 9       7  10-10-2016         8    326                   Danka a Janka
# 10      9  04-10-2016         6    413                 Dievča vo vlaku
# 12     13  29-09-2016         4    336        Harry Potter 1 - 7 (box)
# 14     16  22-09-2016         4    225  Najkrajšie slovenské rozprávky
# 15     29  24-08-2016         4    156               Peklo je otvorené
# 16     62  06-07-2016         1    188              Geniálna priateľka
#
#       price
# 0   12,72 €
# 1   11,01 €
# 3   13,52 €
# 5   13,80 €
# 7   10,59 €
# 9    5,52 €
# 10  10,64 €
# 12  53,31 €
# 14  17,79 €
# 15  12,42 €
# 16  12,45 €

# %%
merged_left = merged_left.sort_values(by='likes', ascending=0)
merged_left.head(11)
# Out:
#     index        date  comments  likes                           title  \
# 1       2  18-10-2016         0    665                  V ľudskej koži
# 18    161  29-01-2016         7    467                       Prezident
# 10      9  04-10-2016         6    413                 Dievča vo vlaku
# 7       5  13-10-2016        12    400           Získaj si jej priazeň
# 17     76  16-06-2016         3    353               Nežná fatamorgána
# 12     13  29-09-2016         4    336        Harry Potter 1 - 7 (box)
# 9       7  10-10-2016         8    326                   Danka a Janka
# 14     16  22-09-2016         4    225  Najkrajšie slovenské rozprávky
# 3       3  15-10-2016         3    216          Nie som žiadna bábovka
# 5       3  15-10-2016         3    216        Príbeh nového priezviska
# 16     62  06-07-2016         1    188              Geniálna priateľka
#
#       price
# 1   11,01 €
# 18  10,32 €
# 10  10,64 €
# 7   10,59 €
# 17  11,53 €
# 12  53,31 €
# 9    5,52 €
# 14  17,79 €
# 3   13,52 €
# 5   13,80 €
# 16  12,45 €

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import *

# %%
merged_left["likes"].plot(kind="bar", alpha=0.5)
plt.title("Total like count per post", fontsize=20)
plt.xlabel("Most likes to least likes")
plt.ylabel("Total likes")

# %%
def agregate(x):
    return Series(dict(Number_of_likes = x["likes"].count(),
                      Number_of_comments = x["comments"].count(),
                      ))

counts = df.groupby(merged_left["title"]).apply(agregate)
counts.head(11)
# Out:
#                                                     Number_of_comments  \
# title
# Bezduché mesto                                                       1
# Biela levica (Severský triler)                                       1
# Danka a Janka                                                        1
# Diabol v zrkadle                                                     1
# Dievča vo vlaku                                                      1
# Divá Bára / Dobrý člověk                                             1
# Ekonómia                                                             1
# Geniálna priateľka                                                   1
# Harry Potter 1 - 7 (box)                                             1
# Harry Potter a Tajomná komnata (kniha 2) (Ilust...                   1
# Hra s ohňom                                                          1
#
#                                                     Number_of_likes
# title
# Bezduché mesto                                                    1
# Biela levica (Severský triler)                                    1
# Danka a Janka                                                     1
# Diabol v zrkadle                                                  1
# Dievča vo vlaku                                                   1
# Divá Bára / Dobrý člověk                                          1
# Ekonómia                                                          1
# Geniálna priateľka                                                1
# Harry Potter 1 - 7 (box)                                          1
# Harry Potter a Tajomná komnata (kniha 2) (Ilust...                1
# Hra s ohňom                                                       1

# %%
counts.to_csv('Number of lines and comments.csv')

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
merged_left[['likes','comments']].describe().T
# Out:
#           count   mean    std   min   25%   50%    75%    max
# likes     29.00 161.24 171.28 12.00 34.00 56.00 225.00 665.00
# comments  29.00   2.86   2.82  0.00  1.00  3.00   4.00  12.00

# %%
merged_left['likes'].corr(df['comments'])
# Out:
# 0.019237615761311336

# %%
merged_left.plot(kind='scatter', x='likes', y='comments')

# %%
merged_left = merged_left[merged_left["comments"] >= 3]
merged_left.head(11)
# Out:
#     index        date  comments  likes                           title  \
# 18    161  29-01-2016         7    467                       Prezident
# 10      9  04-10-2016         6    413                 Dievča vo vlaku
# 7       5  13-10-2016        12    400           Získaj si jej priazeň
# 12     13  29-09-2016         4    336        Harry Potter 1 - 7 (box)
# 9       7  10-10-2016         8    326                   Danka a Janka
# 14     16  22-09-2016         4    225  Najkrajšie slovenské rozprávky
# 15     29  24-08-2016         4    156               Peklo je otvorené
# 0       0  21-10-2016         4    106                            Sova
# 32    454  28-11-2012         6     55        Divá Bára / Dobrý člověk
#
#       price
# 18  10,32 €
# 10  10,64 €
# 7   10,59 €
# 12  53,31 €
# 9    5,52 €
# 14  17,79 €
# 15  12,42 €
# 0   12,72 €
# 32   7,76 €

# %%
merged_left = merged_left.sort_values(by='likes', ascending=0)
merged_left['comments'].plot(kind='line')
plt.title("Total comments per post", fontsize=20)
plt.xlabel("Posts")
plt.ylabel("Total comments")

# %%
merged_left = merged_left.sort_values(by=['comments'], ascending=0)
merged_left
# Out:
#     index        date  comments  likes                           title  \
# 7       5  13-10-2016        12    400           Získaj si jej priazeň
# 9       7  10-10-2016         8    326                   Danka a Janka
# 18    161  29-01-2016         7    467                       Prezident
# 10      9  04-10-2016         6    413                 Dievča vo vlaku
# 32    454  28-11-2012         6     55        Divá Bára / Dobrý člověk
# 12     13  29-09-2016         4    336        Harry Potter 1 - 7 (box)
# 14     16  22-09-2016         4    225  Najkrajšie slovenské rozprávky
# 15     29  24-08-2016         4    156               Peklo je otvorené
# 0       0  21-10-2016         4    106                            Sova
#
#       price
# 7   10,59 €
# 9    5,52 €
# 18  10,32 €
# 10  10,64 €
# 32   7,76 €
# 12  53,31 €
# 14  17,79 €
# 15  12,42 €
# 0   12,72 €

# %%
df_users = pd.read_csv('csv/users.csv', sep=',', low_memory=False)
df_users.head(11)
# Out:
#                 username  index_id
# 0            knihypaseka        16
# 1              gitagitka        13
# 2          crazyboy77777       161
# 3            knihypaseka         7
# 4            knihypaseka       454
# 5              katka3899       161
# 6     kristina.synakova1        13
# 7   essentials.daisydrop        29
# 8          annaprehodova       161
# 9              patrikm18         5
# 10     zemancik.radoslav        29

# %%
users = pd.merge(left=merged_left,right=df_users, how='inner', left_on='index', right_on='index_id')
users = users.drop(['comments', 'likes', 'index_id'], axis=1)
users.head(11)
# Out:
#     index        date                           title    price  \
# 0       5  13-10-2016           Získaj si jej priazeň  10,59 €
# 1       5  13-10-2016           Získaj si jej priazeň  10,59 €
# 2       5  13-10-2016           Získaj si jej priazeň  10,59 €
# 3       5  13-10-2016           Získaj si jej priazeň  10,59 €
# 4       5  13-10-2016           Získaj si jej priazeň  10,59 €
# 5       5  13-10-2016           Získaj si jej priazeň  10,59 €
# 6       7  10-10-2016                   Danka a Janka   5,52 €
# 7       7  10-10-2016                   Danka a Janka   5,52 €
# 8       7  10-10-2016                   Danka a Janka   5,52 €
# 9       7  10-10-2016                   Danka a Janka   5,52 €
# 10      7  10-10-2016                   Danka a Janka   5,52 €
# 11      7  10-10-2016                   Danka a Janka   5,52 €
# 12      7  10-10-2016                   Danka a Janka   5,52 €
# 13      7  10-10-2016                   Danka a Janka   5,52 €
# 14    161  29-01-2016                       Prezident  10,32 €
# 15    161  29-01-2016                       Prezident  10,32 €
# 16    161  29-01-2016                       Prezident  10,32 €
# 17    161  29-01-2016                       Prezident  10,32 €
# 18    161  29-01-2016                       Prezident  10,32 €
# 19    161  29-01-2016                       Prezident  10,32 €
# 20    161  29-01-2016                       Prezident  10,32 €
# 21      9  04-10-2016                 Dievča vo vlaku  10,64 €
# 22      9  04-10-2016                 Dievča vo vlaku  10,64 €
# 23      9  04-10-2016                 Dievča vo vlaku  10,64 €
# 24    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 25    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 26    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 27    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 28    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 29    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 30    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 31    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 32    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 33    454  28-11-2012        Divá Bára / Dobrý člověk   7,76 €
# 34     13  29-09-2016        Harry Potter 1 - 7 (box)  53,31 €
# 35     13  29-09-2016        Harry Potter 1 - 7 (box)  53,31 €
# 36     13  29-09-2016        Harry Potter 1 - 7 (box)  53,31 €
# 37     13  29-09-2016        Harry Potter 1 - 7 (box)  53,31 €
# 38     16  22-09-2016  Najkrajšie slovenské rozprávky  17,79 €
# 39     16  22-09-2016  Najkrajšie slovenské rozprávky  17,79 €
# 40     16  22-09-2016  Najkrajšie slovenské rozprávky  17,79 €
# 41     16  22-09-2016  Najkrajšie slovenské rozprávky  17,79 €
# 42     29  24-08-2016               Peklo je otvorené  12,42 €
# 43     29  24-08-2016               Peklo je otvorené  12,42 €
# 44     29  24-08-2016               Peklo je otvorené  12,42 €
# 45     29  24-08-2016               Peklo je otvorené  12,42 €
# 46     29  24-08-2016               Peklo je otvorené  12,42 €
# 47      0  21-10-2016                            Sova  12,72 €
# 48      0  21-10-2016                            Sova  12,72 €
# 49      0  21-10-2016                            Sova  12,72 €
# 50      0  21-10-2016                            Sova  12,72 €
# 51      0  21-10-2016                            Sova  12,72 €
# 52      0  21-10-2016                            Sova  12,72 €
# 53      0  21-10-2016                            Sova  12,72 €
# 54      0  21-10-2016                            Sova  12,72 €
#
#                 username
# 0              patrikm18
# 1         janka_tomanova
# 2          kristina_kali
# 3             henta__tam
# 4         janka_tomanova
# 5                dasti96
# 6            knihypaseka
# 7          alenkakordiak
# 8          kristina_kali
# 9                ziarivy
# 10           knihypaseka
# 11    kristina.synakova1
# 12        janka_tomanova
# 13    kristina.synakova1
# 14         crazyboy77777
# 15             katka3899
# 16         annaprehodova
# 17             katka3899
# 18               dasti96
# 19     zemancik.radoslav
# 20        janka_tomanova
# 21           knihypaseka
# 22     zemancik.radoslav
# 23               ziarivy
# 24           knihypaseka
# 25         alenkakordiak
# 26  essentials.daisydrop
# 27         annaprehodova
# 28         crazyboy77777
# 29            henta__tam
# 30         crazyboy77777
# 31         kristina_kali
# 32               ziarivy
# 33               ziarivy
# 34             gitagitka
# 35    kristina.synakova1
# 36  essentials.daisydrop
# 37       silviabucsekova
# 38           knihypaseka
# 39  essentials.daisydrop
# 40         kristina_kali
# 41  essentials.daisydrop
# 42  essentials.daisydrop
# 43     zemancik.radoslav
# 44               dasti96
# 45               ziarivy
# 46  essentials.daisydrop
# 47            henta__tam
# 48             katka3899
# 49               ziarivy
# 50               ziarivy
# 51            henta__tam
# 52  essentials.daisydrop
# 53             patrikm18
# 54        janka_tomanova
